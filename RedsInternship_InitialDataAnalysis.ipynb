# %%
# just importing the modules we'll need
# %matplotlib inline
import pandas as pd
import os
import glob
from matplotlib import pyplot as plt
import scipy.stats
from pylab import plot, show, savefig, xlim, figure, \
                hold, ylim, legend, boxplot, setp, axes
    
# let's import our data as a dataframe for easy statistical analysis (td for testing data)
bos = pd.read_csv(os.path.join(os.getcwd(),'BOS_SAFIS_Ex.csv'))

# %%
bos.head()
# Out:
#   Ticket Number         Date     Port  VTR Vessel Name    Gear  \
# 0         BO2924  2018-06-19  Ipswich  NaN          na  Digger
# 1         BO2926  2018-06-19  Ipswich  NaN          na  Digger
# 2         BO2926  2018-06-19  Ipswich  NaN          na  Digger
# 3         BO2940  2018-06-20  Ipswich  NaN          na  Digger
# 4         BO2940  2018-06-20  Ipswich  NaN          na  Digger
#
#                     Species Catagory            Fisher  Weight  Price  \
# 0  Clams - Razors - Ipswich     food      Adiel Merlos      42    3.5
# 1  Clams - Ipswich Steamers     food  Alexander Graham     148    1.5
# 2  Clams - Razors - Ipswich     food  Alexander Graham      41    3.5
# 3  Clams - Ipswich Steamers     food  Alexander Graham     185    1.5
# 4  Clams - Razors - Ipswich     food  Alexander Graham      10    3.0
#
#   Shellfish Area
# 0             N7
# 1             N4
# 2             N4
# 3             N4
# 4             N4

# %%
bos.set_index('Port', inplace=True)
bos.groupby('Species')['Weight'].plot(legend=True)
# Out:
# Species
# Bigeye                          AxesSubplot(0.125,0.125;0.775x0.755)
# Black Backs                     AxesSubplot(0.125,0.125;0.775x0.755)
# Black Backs - Large             AxesSubplot(0.125,0.125;0.775x0.755)
# Black Backs - Mix               AxesSubplot(0.125,0.125;0.775x0.755)
# Black Backs - PeeWee            AxesSubplot(0.125,0.125;0.775x0.755)
# Black Backs - Small             AxesSubplot(0.125,0.125;0.775x0.755)
# Black Seabass - Jumbo           AxesSubplot(0.125,0.125;0.775x0.755)
# Black Seabass - Large           AxesSubplot(0.125,0.125;0.775x0.755)
# Black Seabass - Medium          AxesSubplot(0.125,0.125;0.775x0.755)
# Bluefish                        AxesSubplot(0.125,0.125;0.775x0.755)
# Bonita                          AxesSubplot(0.125,0.125;0.775x0.755)
# Boston Mackerel                 AxesSubplot(0.125,0.125;0.775x0.755)
# Clams - Blood Clams             AxesSubplot(0.125,0.125;0.775x0.755)
# ...
